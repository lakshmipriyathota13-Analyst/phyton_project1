# %%
#1. Check whether a number is positive or negative.

n1=int(input("enter num"))

if(n1 >=0):
    print(n1,"is a Positive Number")
    
else:
    print(n1,"is a Negative Number")
# Out:
# enter num 5
# 5 is a positive no

# %%
#2. Check whether a number is even or odd.

n1=int(input("enter no"))

if(n1%2==0):
    print(n1,"is an Even Number")
else:
    print(n1,"is a Odd Number")
# Out:
# enter no 6
# 6 is an Even Number

# %%
#3. Check whether a person is eligible to vote.

name=input("enter name")
age=int(input("enter age"))

if(age>=18):
    print("Eligible for voting")
else:
    print("Not Eligible for voting")
# Out:
# enter name priya
# enter age 27
# Eligible for voting

# %%
#4. Find the greater of two numbers.

Num1=int(input("enter your first no"))
Num2=int(input("enter your second no"))

if(Num1>Num2):
 print(f"{Num1} is Greater than{Num2}")
elif(Num2>Num1):
 print(f"{Num2} is Greater than{Num1}")
else:
 print(f"Both Numbers are equal")
# Out:
# enter your first no 25
# enter your second no 35
# 35 is Greater than25

# %%
#5. Check whether a student has passed or failed. Passing marks are 40.

subject1=int(input("enter subject1 marks"))
subject2=int(input("enter  subject2 marks"))
subject3=int(input("enter subject3 marks"))

total_marks=subject1+subject2+subject3
average=total_marks/3

if(average>=90):
    print("Out Standing")
elif(average<=89 and average>=70):
    print("A Grade")
elif(average<=69 and average>=50):
    print("B Grade")
elif(average<=49 and average>=40):
    print("C Grade")
else:
    print("Failed")
# Out:
# enter subject1 marks 85
# enter  subject2 marks 96
# enter subject3 marks 93
# Out Standing

# %%
#6. Check whether a number is divisible by 5.

Num1=int(input("enter your first no"))

if(Num1%5==0):
    print(Num1,"is Divisible by 5")
else:
    print(Num1,"is not Divisible by 5")
# Out:
# enter your first no 25
# 25 is Divisible by 5

# %%
#7. Check whether a person is eligible for a driving license.

name=input("enter your name")
age=int(input("enter your age"))

theory_marks=int(input("enter your theory marks"))
practical_marks=int(input("enter your practical marks"))

if(theory_marks>=80) and (practical_marks>=70):
    print(name,"You are Eligible for Driving Licence")
else:
    print(name,"You are not Eligible for Driving Licence")
# Out:
# enter your name priya
# enter your age 27
# enter your theory marks 90
# enter your practical marks 95
# priya You are Eligible for Driving Licence

# %%
#8. Display a grade based on the student's marks.

marks=int(input("enter marks"))

if(marks <=100 and marks>=80):
    print("A Grade")
elif(marks<=79 and marks>=60):
    print("B Grade")
elif(marks <=59 and marks>=40):
    print("C Grade")
else:
    print("Fail")
# Out:
# enter marks 95
# A Grade

# %%
#9. Check whether a given year is a leap year.

#A year is a leap year if:
#It is divisible by 4, and
#Not divisible by 100, unless it is also divisible by 400.

year=int(input("enter your year"))

if(year%4==0):
 print("Leap Year")
elif (year%400==0):
    print("Leap Year")
else:
    print("not a leap year")
# Out:
# enter your year 2014
# not a leap year

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(f"{year} is a Leap Year")
else:
    print(f"{year} is NOT a Leap Year")
# Out:
# Enter a year:  2016
# 2016 is a Leap Year

# %%
#10. Create a simple calculator using +, -, *, and /.

print(f"1.Sum")
print(f"2.Subtraction")
print(f"3.Multiplication")
print(f"4.Division")

choice=int(input("enter your choice"))

n1=int(input("enter your first no"))
n2=int(input("enter your second no"))

if choice==1:
    n3=n1+n2

elif choice==2:
    n3=abs(n1-n2)
    
elif choice==3:
    n3=n1*n2
    
elif choice==4:
     n3=n1/n2
    
else:
  print("invalid choice")
    
print(n3)
# Out:
# 1.Sum
# 2.Subtraction
# 3.Multiplication
# 4.Division
# enter your choice 3
# enter your first no 50
# enter your second no 5
# 250
