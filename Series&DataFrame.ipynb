# %%
#Create a sereis 
import pandas as pd
Fruits=pd.Series(["Apple","Banana","Mango","kiwi","Papaya","Grapes"])
print(Fruits)
# Out:
# 0     Apple
# 1    Banana
# 2     Mango
# 3      kiwi
# 4    Papaya
# 5    Grapes
# dtype: object

# %%
#Create a series with custom index
Sales=pd.Series([50000,145000,175000,215000],index=["cloths","Furniture","Kitchen Appliance","Electronics"])
print(Sales)
# Out:
# cloths                50000
# Furniture            145000
# Kitchen Appliance    175000
# Electronics          215000
# dtype: int64

# %%
#create a series of student names and marks
Students=pd.Series([75,89,96,54,71,35,42],index=["Ram","Mokshit","Priya","Pradeep","Arjun","Kiran","Vani"])
print(Students)
# Out:
# Ram        75
# Mokshit    89
# Priya      96
# Pradeep    54
# Arjun      71
# Kiran      35
# Vani       42
# dtype: int64

# %%
#create a series list for sales and days
Amount=[10000,15000,25000,27000,30000,45000,65000]
Day=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
Sales=pd.Series(Amount,index=Day)
print(Sales["Friday"])
# Out:
# 30000

# %%
# take  day name from the user then check  it is in day list or not if is in day list then show 

# sales otherwise print invalid day (In )

Amount=[10000,15000,25000,27000,30000,45000,65000]
Day=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
Day_nm=input("enter a day")
if Day_nm in Day:
    print(Day_nm,"Available")
else:
    print("Not Available")

print(Sales[Sales>30000])
# Out:
# enter a day Friday
# Friday Available
# Saturday    45000
# Sunday      65000
# dtype: int64

# %%
# Sum of sales
s=[100,200,300,400,500,600,700]

day=["Mon","Tues","Wed","Thur","Fri","Sat","Sun"]

Sales=pd.Series(s,index=day)
print(Sales.head(3))
print(Sales.tail(2))
print(Sales.sum())
print(Sales.min())
print(Sales.max())
# Out:
# Mon     100
# Tues    200
# Wed     300
# dtype: int64
# Sat    600
# Sun    700
# dtype: int64
# 2800
# 100
# 700

# %%
import numpy as np

s=[100,np.nan,300,400,500,np.nan,700]

day=["Mon","Tues","Wed","Thur","Fri","Sat","Sun"]

Sales=pd.Series(s,index=day)

print(Sales)

print(Sales.isnull())

print(Sales.isnull().sum())   

#Sales=Sales.dropna() #  to drop null value

Sales=Sales.fillna(0)   

Sales=Sales.fillna(Sales.max())   
print(Sales.isnull().sum())
print(Sales)
# Out:
# Mon     100.0
# Tues      NaN
# Wed     300.0
# Thur    400.0
# Fri     500.0
# Sat       NaN
# Sun     700.0
# dtype: float64
# Mon     False
# Tues     True
# Wed     False
# Thur    False
# Fri     False
# Sat      True
# Sun     False
# dtype: bool
# 2
# 0
# Mon     100.0
# Tues      0.0
# Wed     300.0
# Thur    400.0
# Fri     500.0
# Sat       0.0
# Sun     700.0
# dtype: float64

# %%
import pandas as pd
Employees={"Name":["Priya","Pradeep","Kumar","Vani","Ram","Mokshith","Arjun","Shiva","Ajay","Lakshmi"],
           "Age":[27,26,29,31,21,25,23,35,33,39],
           "Department":["IT","Marketing","Admin","HR","Non IT","Finance","IT","Marketing","Operations","IT"],
           "Email_id":["p@gmail.com","pradeep@gmail.com","Kumar@gmail.com","Vani@gmail.com","Ram@gmail.com","mokshi@gmail.com","Arju@gmail.com","shiv@gmail.com","ajay@gmail.com","laks@gmail.com"],
           "Salary":[85000,90000,45000,60000,40000,55000,50000,45000,25000,35000] }

City=["guntur","preston","tenali","vijayawada","hyderabad","bnaglore","guntur","tenali","vijayawada","tirupathi"]
df=pd.DataFrame(Employees)
df["City"]=City

df["Bonus"]=df["Salary"]*15/100

df["Total_Salary"]=df["Salary"]+df["Bonus"]

print(df[df["Salary"]>=85000])

print(df[df["City"]=="guntur"])

print(df[df["Department"]=="IT"])

print(df[df["Department"]=="IT"]["Email_id"])

print(df[ (df['Department']=="IT") & (df['Salary']>50000 ) ])  # AnD

print(df[ (df['Department']=="IT")|(df['Salary']>50000 ) ])   # OR
print(df[["Name","Salary","Department"]])
# Out:
#       Name  Age Department           Email_id  Salary     City    Bonus  \
# 0    Priya   27         IT        p@gmail.com   85000   guntur  12750.0
# 1  Pradeep   26  Marketing  pradeep@gmail.com   90000  preston  13500.0
#
#    Total_Salary
# 0       97750.0
# 1      103500.0
#     Name  Age Department        Email_id  Salary    City    Bonus  \
# 0  Priya   27         IT     p@gmail.com   85000  guntur  12750.0
# 6  Arjun   23         IT  Arju@gmail.com   50000  guntur   7500.0
#
#    Total_Salary
# 0       97750.0
# 6       57500.0
#       Name  Age Department        Email_id  Salary       City    Bonus  \
# 0    Priya   27         IT     p@gmail.com   85000     guntur  12750.0
# 6    Arjun   23         IT  Arju@gmail.com   50000     guntur   7500.0
# 9  Lakshmi   39         IT  laks@gmail.com   35000  tirupathi   5250.0
#
#    Total_Salary
# 0       97750.0
# 6       57500.0
# 9       40250.0
# 0       p@gmail.com
# 6    Arju@gmail.com
# 9    laks@gmail.com
# ...

# %%
Employees=pd.Series(["Priya","Pradeep","Kumar","Vani","Ram","Mokshith","Arjun","Shiva","Ajay","Lakshmi"],index=[101,102,103,104,105,106,107,108,109,110])
print(Employees)
# Out:
# 101       Priya
# 102     Pradeep
# 103       Kumar
# 104        Vani
# 105         Ram
# 106    Mokshith
# 107       Arjun
# 108       Shiva
# 109        Ajay
# 110     Lakshmi
# dtype: object

# %%
import pandas as pd
data = {"Loan_ID": [1001, 1002, 1003, 1004, 1005,

        1006, 1007, 1008, 1009, 1010,

        1011, 1012, 1013, 1014, 1015,

        1016, 1017, 1018, 1019, 1020],
        "Applicant_Name": [

        "Rahul Sharma", "Priya Verma", "Amit Kumar", "Neha Singh", "Rohan Mehta",

        "Anjali Gupta", "Vikas Yadav", "Sneha Kapoor", "Arjun Malhotra", "Pooja Jain",

        "Karan Patel", "Simran Kaur", "Manish Sharma", "Ritika Joshi", "Aditya Rao",

        "Nisha Agarwal", "Suresh Kumar", "Meena Rani", "Varun Gupta", "Kavita Singh" ],
        
         "Age": [

        28, 35, 42, 31, 29,

        45, 38, 27, 33, 40,

        36, 30, 48, 26, 34,

        39, 44, 32, 37, 41 ],
        
        "Gender": [

        "Male", "Female", "Male", "Female", "Male",

        "Female", "Male", "Female", "Male", "Female",

        "Male", "Female", "Male", "Female", "Male",

        "Female", "Male", "Female", "Male", "Female"],
         "Income": [

        45000, 60000, 75000, 52000, 48000,

        90000, 68000, 42000, 80000, 55000,

        72000, 65000, 95000, 40000, 70000,

        58000, 85000, 50000, 78000, 62000],
        "Loan_Amount": [

        250000, 400000, 600000, 300000, 275000,

        800000, 500000, 200000, 650000, 350000,

        550000, 450000, 900000, 180000, 500000,

        375000, 700000, 280000, 620000, 420000],
        "Loan_Term": [

        5, 10, 15, 7, 5,

        20, 15, 5, 20, 10,

        15, 10, 20, 5, 15,

        10, 20, 7, 15, 10],
        "Credit_Score": [

        720, 680, 750, 690, 710,

        800, 740, 650, 780, 700,

        730, 690, 810, 640, 760,

        710, 790, 675, 745, 700 ],

 

        "Employment_Type": [

        "Salaried", "Self-Employed", "Salaried", "Salaried", "Business",

        "Salaried", "Business", "Salaried", "Salaried", "Self-Employed",

        "Salaried", "Business", "Salaried", "Salaried", "Business",

        "Salaried", "Self-Employed", "Salaried", "Business", "Salaried"],
        "Loan_Status": [

        "Approved", "Approved", "Approved", "Approved", "Rejected",

        "Approved", "Approved", "Rejected", "Approved", "Approved",

        "Approved", "Rejected", "Approved", "Rejected", "Approved",

        "Approved", "Approved", "Rejected", "Approved", "Approved"]}


df=pd.DataFrame(data)


print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 0      1001    Rahul Sharma   28    Male   45000       250000          5
# 1      1002     Priya Verma   35  Female   60000       400000         10
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 3      1004      Neha Singh   31  Female   52000       300000          7
# 4      1005     Rohan Mehta   29    Male   48000       275000          5
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 6      1007     Vikas Yadav   38    Male   68000       500000         15
# 7      1008    Sneha Kapoor   27  Female   42000       200000          5
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 9      1010      Pooja Jain   40  Female   55000       350000         10
# 10     1011     Karan Patel   36    Male   72000       550000         15
# 11     1012     Simran Kaur   30  Female   65000       450000         10
# ...

# %%
# 1. Add a new column Annual_Income by multiplying Income by 12.
df["Annual_income"]=df["Income"]*12
print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 0      1001    Rahul Sharma   28    Male   45000       250000          5
# 1      1002     Priya Verma   35  Female   60000       400000         10
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 3      1004      Neha Singh   31  Female   52000       300000          7
# 4      1005     Rohan Mehta   29    Male   48000       275000          5
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 6      1007     Vikas Yadav   38    Male   68000       500000         15
# 7      1008    Sneha Kapoor   27  Female   42000       200000          5
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 9      1010      Pooja Jain   40  Female   55000       350000         10
# 10     1011     Karan Patel   36    Male   72000       550000         15
# 11     1012     Simran Kaur   30  Female   65000       450000         10
# ...

# %%
#2. Add a new column Loan_Amount_Lakhs by dividing Loan_Amount by 100000.
df["Loan_Amount_Lakhs"]=df["Loan_Amount"]/10000
print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 0      1001    Rahul Sharma   28    Male   45000       250000          5
# 1      1002     Priya Verma   35  Female   60000       400000         10
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 3      1004      Neha Singh   31  Female   52000       300000          7
# 4      1005     Rohan Mehta   29    Male   48000       275000          5
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 6      1007     Vikas Yadav   38    Male   68000       500000         15
# 7      1008    Sneha Kapoor   27  Female   42000       200000          5
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 9      1010      Pooja Jain   40  Female   55000       350000         10
# 10     1011     Karan Patel   36    Male   72000       550000         15
# 11     1012     Simran Kaur   30  Female   65000       450000         10
# ...

# %%
#3. Display applicants whose Income is greater than 60000.
print(df[df["Income"]>60000])
print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 6      1007     Vikas Yadav   38    Male   68000       500000         15
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 10     1011     Karan Patel   36    Male   72000       550000         15
# 11     1012     Simran Kaur   30  Female   65000       450000         10
# 12     1013   Manish Sharma   48    Male   95000       900000         20
# 14     1015      Aditya Rao   34    Male   70000       500000         15
# 16     1017    Suresh Kumar   44    Male   85000       700000         20
# 18     1019     Varun Gupta   37    Male   78000       620000         15
# 19     1020    Kavita Singh   41  Female   62000       420000         10
#
#     Credit_Score Employment_Type Loan_Status  Annual_income  Loan_Amount_Lakhs
# ...

# %%
#4. Display applicants whose Loan_Amount is greater than 500000.
print(df[df["Loan_Amount"]>500000])
print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 10     1011     Karan Patel   36    Male   72000       550000         15
# 12     1013   Manish Sharma   48    Male   95000       900000         20
# 16     1017    Suresh Kumar   44    Male   85000       700000         20
# 18     1019     Varun Gupta   37    Male   78000       620000         15
#
#     Credit_Score Employment_Type Loan_Status  Annual_income  Loan_Amount_Lakhs
# 2            750        Salaried    Approved         900000               60.0
# 5            800        Salaried    Approved        1080000               80.0
# 8            780        Salaried    Approved         960000               65.0
# ...

# %%
#5. Display applicants whose Credit_Score is greater than 750.
print(df[df["Credit_Score"]>750])
print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 12     1013   Manish Sharma   48    Male   95000       900000         20
# 14     1015      Aditya Rao   34    Male   70000       500000         15
# 16     1017    Suresh Kumar   44    Male   85000       700000         20
#
#     Credit_Score Employment_Type Loan_Status  Annual_income  Loan_Amount_Lakhs
# 5            800        Salaried    Approved        1080000               80.0
# 8            780        Salaried    Approved         960000               65.0
# 12           810        Salaried    Approved        1140000               90.0
# 14           760        Business    Approved         840000               50.0
# 16           790   Self-Employed    Approved        1020000               70.0
# ...

# %%
#6. Display applicants whose Loan_Status is "Approved".
print(df[df["Loan_Status"]=="Approved"])
print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 0      1001    Rahul Sharma   28    Male   45000       250000          5
# 1      1002     Priya Verma   35  Female   60000       400000         10
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 3      1004      Neha Singh   31  Female   52000       300000          7
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 6      1007     Vikas Yadav   38    Male   68000       500000         15
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 9      1010      Pooja Jain   40  Female   55000       350000         10
# 10     1011     Karan Patel   36    Male   72000       550000         15
# 12     1013   Manish Sharma   48    Male   95000       900000         20
# 14     1015      Aditya Rao   34    Male   70000       500000         15
# 15     1016   Nisha Agarwal   39  Female   58000       375000         10
# ...

# %%
#7.Display only Female applicants.
print(df[df["Gender"]=="Female"])
print(df)
# Out:
#     Loan_ID Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 1      1002    Priya Verma   35  Female   60000       400000         10
# 3      1004     Neha Singh   31  Female   52000       300000          7
# 5      1006   Anjali Gupta   45  Female   90000       800000         20
# 7      1008   Sneha Kapoor   27  Female   42000       200000          5
# 9      1010     Pooja Jain   40  Female   55000       350000         10
# 11     1012    Simran Kaur   30  Female   65000       450000         10
# 13     1014   Ritika Joshi   26  Female   40000       180000          5
# 15     1016  Nisha Agarwal   39  Female   58000       375000         10
# 17     1018     Meena Rani   32  Female   50000       280000          7
# 19     1020   Kavita Singh   41  Female   62000       420000         10
#
#     Credit_Score Employment_Type Loan_Status  Annual_income  Loan_Amount_Lakhs
# 1            680   Self-Employed    Approved         720000               40.0
# ...

# %%
#8.Display applicants whose Income is less than 50000.
print(df[df["Income"]<50000])
print(df)
# Out:
#     Loan_ID Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 0      1001   Rahul Sharma   28    Male   45000       250000          5
# 4      1005    Rohan Mehta   29    Male   48000       275000          5
# 7      1008   Sneha Kapoor   27  Female   42000       200000          5
# 13     1014   Ritika Joshi   26  Female   40000       180000          5
#
#     Credit_Score Employment_Type Loan_Status  Annual_income  Loan_Amount_Lakhs
# 0            720        Salaried    Approved         540000               25.0
# 4            710        Business    Rejected         576000               27.5
# 7            650        Salaried    Rejected         504000               20.0
# 13           640        Salaried    Rejected         480000               18.0
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 0      1001    Rahul Sharma   28    Male   45000       250000          5
# ...

# %%
#9. Display applicants whose Loan_Amount is equal to 500000.
print(df[df["Loan_Amount"]==500000])
print(df)
# Out:
#     Loan_ID Applicant_Name  Age Gender  Income  Loan_Amount  Loan_Term  \
# 6      1007    Vikas Yadav   38   Male   68000       500000         15
# 14     1015     Aditya Rao   34   Male   70000       500000         15
#
#     Credit_Score Employment_Type Loan_Status  Annual_income  Loan_Amount_Lakhs
# 6            740        Business    Approved         816000               50.0
# 14           760        Business    Approved         840000               50.0
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 0      1001    Rahul Sharma   28    Male   45000       250000          5
# 1      1002     Priya Verma   35  Female   60000       400000         10
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 3      1004      Neha Singh   31  Female   52000       300000          7
# 4      1005     Rohan Mehta   29    Male   48000       275000          5
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# ...

# %%
#10. Display applicants whose Age is greater than 30 AND Loan_Status is "Approved".

print(df[(df['Age']>30) & (df['Loan_Status']=="Approved")])

print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 1      1002     Priya Verma   35  Female   60000       400000         10
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 3      1004      Neha Singh   31  Female   52000       300000          7
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 6      1007     Vikas Yadav   38    Male   68000       500000         15
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 9      1010      Pooja Jain   40  Female   55000       350000         10
# 10     1011     Karan Patel   36    Male   72000       550000         15
# 12     1013   Manish Sharma   48    Male   95000       900000         20
# 14     1015      Aditya Rao   34    Male   70000       500000         15
# 15     1016   Nisha Agarwal   39  Female   58000       375000         10
# 16     1017    Suresh Kumar   44    Male   85000       700000         20
# ...

# %%
#11. Display applicants whose Employment_Type is "Salaried" OR whose Gender is "Male".
print(df[(df['Employment_Type']=="Salaried") | (df['Gender']=="Male")])
print(df)
# Out:
#     Loan_ID  Applicant_Name  Age  Gender  Income  Loan_Amount  Loan_Term  \
# 0      1001    Rahul Sharma   28    Male   45000       250000          5
# 2      1003      Amit Kumar   42    Male   75000       600000         15
# 3      1004      Neha Singh   31  Female   52000       300000          7
# 4      1005     Rohan Mehta   29    Male   48000       275000          5
# 5      1006    Anjali Gupta   45  Female   90000       800000         20
# 6      1007     Vikas Yadav   38    Male   68000       500000         15
# 7      1008    Sneha Kapoor   27  Female   42000       200000          5
# 8      1009  Arjun Malhotra   33    Male   80000       650000         20
# 10     1011     Karan Patel   36    Male   72000       550000         15
# 12     1013   Manish Sharma   48    Male   95000       900000         20
# 13     1014    Ritika Joshi   26  Female   40000       180000          5
# 14     1015      Aditya Rao   34    Male   70000       500000         15
# ...
