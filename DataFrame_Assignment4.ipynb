# %%
import pandas as pd

data = {
    "Employee_ID": [
        101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
        111, 112, 113, 114, 115, 116, 117, 118, 119, 120,
        121, 122, 123, 124, 125, 126, 127, 128, 129, 130
    ],

    "Employee_Name": [
        "Amit", "Priya", "Rahul", "Neha", "Vikas", "Sneha", "Arjun", "Pooja",
        "Karan", "Riya", "Ankit", "Meena", "Rohit", "Simran", "Varun",
        "Kavita", "Manish", "Nisha", "Suresh", "Anjali", "Deepak", "Pallavi",
        "Raj", "Swati", "Mohit", "Komal", "Vivek", "Preeti", "Nitin", "Shweta"
    ],

    "Department": [
        "Sales", "HR", "IT", "Sales", "Finance", "IT", "Sales", "HR",
        "Finance", "IT", "Sales", "HR", "IT", "Finance", "Sales",
        "IT", "HR", "Sales", "Finance", "IT", "Sales", "HR", "Finance",
        "IT", "Sales", "HR", "Finance", "Sales", "IT", "HR"
    ],

    "City": [
        "Delhi", "Mumbai", "Delhi", "Pune", "Mumbai", "Delhi", "Pune", "Chennai",
        "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune", "Mumbai", "Chennai",
        "Delhi", "Jaipur", "Mumbai", "Delhi", "Pune", "Chennai", "Delhi",
        "Mumbai", "Pune", "Delhi", "Jaipur", "Mumbai", "Chennai", "Delhi", "Mumbai"
    ],

    "Experience": [
        2, 5, 3, 7, 4, 6, 2, 8, 5, 3,
        4, 6, 2, 9, 5, 3, 7, 4, 8, 2,
        6, 5, 3, 7, 4, 8, 2, 6, 5, 9
    ],

    "Salary": [
        30000, 50000, 42000, 65000, 45000, 60000, 32000, 70000, 55000, 40000,
        48000, 52000, 38000, 75000, 58000, 43000, 62000, 47000, 68000, 35000,
        56000, 51000, 39000, 64000, 46000, 72000, 33000, 59000, 54000, 78000
    ],

    "Performance_Score": [
        75, 88, 82, 91, 79, 95, 70, 89, 84, 76,
        87, 90, 72, 96, 85, 78, 92, 81, 94, 69,
        86, 83, 77, 90, 80, 93, 71, 88, 85, 97
    ],

    "Projects_Completed": [
        4, 7, 5, 9, 6, 10, 3, 8, 7, 5,
        6, 8, 4, 11, 7, 5, 9, 6, 10, 3,
        8, 7, 5, 9, 6, 10, 4, 8, 7, 12
    ],

    "Attendance": [
        92, 96, 88, 94, 90, 97, 85, 93, 91, 89,
        95, 98, 87, 96, 92, 90, 94, 88, 97, 84,
        93, 91, 89, 95, 90, 98, 86, 94, 92, 97
    ]
}

df = pd.DataFrame(data)

print(df.head(5))
# Out:
#    Employee_ID Employee_Name Department    City  Experience  Salary  \
# 0          101          Amit      Sales   Delhi           2   30000
# 1          102         Priya         HR  Mumbai           5   50000
# 2          103         Rahul         IT   Delhi           3   42000
# 3          104          Neha      Sales    Pune           7   65000
# 4          105         Vikas    Finance  Mumbai           4   45000
#
#    Performance_Score  Projects_Completed  Attendance
# 0                 75                   4          92
# 1                 88                   7          96
# 2                 82                   5          88
# 3                 91                   9          94
# 4                 79                   6          90

# %%
#1.	Display the first 10 rows.
print(df.head(10))
# Out:
#    Employee_ID Employee_Name Department     City  Experience  Salary  \
# 0          101          Amit      Sales    Delhi           2   30000
# 1          102         Priya         HR   Mumbai           5   50000
# 2          103         Rahul         IT    Delhi           3   42000
# 3          104          Neha      Sales     Pune           7   65000
# 4          105         Vikas    Finance   Mumbai           4   45000
# 5          106         Sneha         IT    Delhi           6   60000
# 6          107         Arjun      Sales     Pune           2   32000
# 7          108         Pooja         HR  Chennai           8   70000
# 8          109         Karan    Finance    Delhi           5   55000
# 9          110          Riya         IT   Mumbai           3   40000
#
#    Performance_Score  Projects_Completed  Attendance
# 0                 75                   4          92
# 1                 88                   7          96
# ...

# %%
#2.	Display only Employee_Name, Department, Salary, and Performance_Score.
print(df[["Employee_Name","Department","Salary","Performance_Score"]])
# Out:
#    Employee_Name Department  Salary  Performance_Score
# 0           Amit      Sales   30000                 75
# 1          Priya         HR   50000                 88
# 2          Rahul         IT   42000                 82
# 3           Neha      Sales   65000                 91
# 4          Vikas    Finance   45000                 79
# 5          Sneha         IT   60000                 95
# 6          Arjun      Sales   32000                 70
# 7          Pooja         HR   70000                 89
# 8          Karan    Finance   55000                 84
# 9           Riya         IT   40000                 76
# 10         Ankit      Sales   48000                 87
# 11         Meena         HR   52000                 90
# 12         Rohit         IT   38000                 72
# 13        Simran    Finance   75000                 96
# 14         Varun      Sales   58000                 85
# 15        Kavita         IT   43000                 78
# ...

# %%
#3.	Find the total number of employees.
print(df["Employee_Name"].count())
# Out:
# 30

# %%
#4.	Display employees whose salary is greater than 50,000.
print(df[df["Salary"]>50000])
# Out:
#     Employee_ID Employee_Name Department     City  Experience  Salary  \
# 3           104          Neha      Sales     Pune           7   65000
# 5           106         Sneha         IT    Delhi           6   60000
# 7           108         Pooja         HR  Chennai           8   70000
# 8           109         Karan    Finance    Delhi           5   55000
# 11          112         Meena         HR    Delhi           6   52000
# 13          114        Simran    Finance   Mumbai           9   75000
# 14          115         Varun      Sales  Chennai           5   58000
# 16          117        Manish         HR   Jaipur           7   62000
# 18          119        Suresh    Finance    Delhi           8   68000
# 20          121        Deepak      Sales  Chennai           6   56000
# 21          122       Pallavi         HR    Delhi           5   51000
# 23          124         Swati         IT     Pune           7   64000
# ...

# %%
#5.	Display employees who belong to the IT department.
print(df[df["Department"]=="IT"])
# Out:
#     Employee_ID Employee_Name Department    City  Experience  Salary  \
# 2           103         Rahul         IT   Delhi           3   42000
# 5           106         Sneha         IT   Delhi           6   60000
# 9           110          Riya         IT  Mumbai           3   40000
# 12          113         Rohit         IT    Pune           2   38000
# 15          116        Kavita         IT   Delhi           3   43000
# 19          120        Anjali         IT    Pune           2   35000
# 23          124         Swati         IT    Pune           7   64000
# 28          129         Nitin         IT   Delhi           5   54000
#
#     Performance_Score  Projects_Completed  Attendance
# 2                  82                   5          88
# 5                  95                  10          97
# 9                  76                   5          89
# 12                 72                   4          87
# 15                 78                   5          90
# ...

# %%
#6.	Find the average salary of all employees.
print(df["Salary"].mean())
# Out:
# 52233.333333333336

# %%
#7.	Display employees whose performance score is greater than 90 AND attendance is greater than 95.
print(df[(df["Performance_Score"]>90) & (df["Attendance"]>95)])
# Out:
#     Employee_ID Employee_Name Department    City  Experience  Salary  \
# 5           106         Sneha         IT   Delhi           6   60000
# 13          114        Simran    Finance  Mumbai           9   75000
# 18          119        Suresh    Finance   Delhi           8   68000
# 25          126         Komal         HR  Jaipur           8   72000
# 29          130        Shweta         HR  Mumbai           9   78000
#
#     Performance_Score  Projects_Completed  Attendance
# 5                  95                  10          97
# 13                 96                  11          96
# 18                 94                  10          97
# 25                 93                  10          98
# 29                 97                  12          97

# %%
#8.	Find the highest salary.
print(df["Salary"].max())
# Out:
# 78000

# %%
#9.	Display employees from Delhi OR Mumbai.
print(df[(df["City"]=="Delhi")| (df["City"]=="Mumbai")])
# Out:
#     Employee_ID Employee_Name Department    City  Experience  Salary  \
# 0           101          Amit      Sales   Delhi           2   30000
# 1           102         Priya         HR  Mumbai           5   50000
# 2           103         Rahul         IT   Delhi           3   42000
# 4           105         Vikas    Finance  Mumbai           4   45000
# 5           106         Sneha         IT   Delhi           6   60000
# 8           109         Karan    Finance   Delhi           5   55000
# 9           110          Riya         IT  Mumbai           3   40000
# 11          112         Meena         HR   Delhi           6   52000
# 13          114        Simran    Finance  Mumbai           9   75000
# 15          116        Kavita         IT   Delhi           3   43000
# 17          118         Nisha      Sales  Mumbai           4   47000
# 18          119        Suresh    Finance   Delhi           8   68000
# 21          122       Pallavi         HR   Delhi           5   51000
# ...

# %%
#10.Add a column Annual_Salary by multiplying Salary by 12.
df["Annual_Salary"]=df["Salary"]*12
print(df)
# Out:
#     Employee_ID Employee_Name Department     City  Experience  Salary  \
# 0           101          Amit      Sales    Delhi           2   30000
# 1           102         Priya         HR   Mumbai           5   50000
# 2           103         Rahul         IT    Delhi           3   42000
# 3           104          Neha      Sales     Pune           7   65000
# 4           105         Vikas    Finance   Mumbai           4   45000
# 5           106         Sneha         IT    Delhi           6   60000
# 6           107         Arjun      Sales     Pune           2   32000
# 7           108         Pooja         HR  Chennai           8   70000
# 8           109         Karan    Finance    Delhi           5   55000
# 9           110          Riya         IT   Mumbai           3   40000
# 10          111         Ankit      Sales   Jaipur           4   48000
# 11          112         Meena         HR    Delhi           6   52000
# ...

# %%
#11.Find the average performance score.
print(df["Performance_Score"].mean())
# Out:
# 84.1

# %%
#12.Display employees who have completed more than 7 projects.
print(df[df["Projects_Completed"]>7])
# Out:
#     Employee_ID Employee_Name Department     City  Experience  Salary  \
# 3           104          Neha      Sales     Pune           7   65000
# 5           106         Sneha         IT    Delhi           6   60000
# 7           108         Pooja         HR  Chennai           8   70000
# 11          112         Meena         HR    Delhi           6   52000
# 13          114        Simran    Finance   Mumbai           9   75000
# 16          117        Manish         HR   Jaipur           7   62000
# 18          119        Suresh    Finance    Delhi           8   68000
# 20          121        Deepak      Sales  Chennai           6   56000
# 23          124         Swati         IT     Pune           7   64000
# 25          126         Komal         HR   Jaipur           8   72000
# 27          128        Preeti      Sales  Chennai           6   59000
# 29          130        Shweta         HR   Mumbai           9   78000
#
# ...

# %%
#13.Find the total salary paid by each department.
print(df.groupby("Department")["Salary"].sum())
# Out:
# Department
# Finance    315000
# HR         435000
# IT         376000
# Sales      441000
# Name: Salary, dtype: int64

# %%
#14.	Remove the Attendance column.
df.drop("Attendance",axis=1,inplace=True)
print(df.head(5))
# Out:
#    Employee_ID Employee_Name Department    City  Experience  Salary  \
# 0          101          Amit      Sales   Delhi           2   30000
# 1          102         Priya         HR  Mumbai           5   50000
# 2          103         Rahul         IT   Delhi           3   42000
# 3          104          Neha      Sales    Pune           7   65000
# 4          105         Vikas    Finance  Mumbai           4   45000
#
#    Performance_Score  Projects_Completed  Annual_Salary
# 0                 75                   4         360000
# 1                 88                   7         600000
# 2                 82                   5         504000
# 3                 91                   9         780000
# 4                 79                   6         540000

# %%
#15.Find the average salary for each department.
print(df.groupby("Department")["Salary"].mean())
# Out:
# Department
# Finance    52500.000000
# HR         62142.857143
# IT         47000.000000
# Sales      49000.000000
# Name: Salary, dtype: float64

# %%
#16.	Display employees who are not from Delhi.
df[df["City"]!="Delhi"]
print(df.head(5))
# Out:
#    Employee_ID Employee_Name Department    City  Experience  Salary  \
# 0          101          Amit      Sales   Delhi           2   30000
# 1          102         Priya         HR  Mumbai           5   50000
# 2          103         Rahul         IT   Delhi           3   42000
# 3          104          Neha      Sales    Pune           7   65000
# 4          105         Vikas    Finance  Mumbai           4   45000
#
#    Performance_Score  Projects_Completed  Annual_Salary
# 0                 75                   4         360000
# 1                 88                   7         600000
# 2                 82                   5         504000
# 3                 91                   9         780000
# 4                 79                   6         540000

# %%
#17.Find the number of employees in each department.
print(df.groupby("Department")["Employee_ID"].count())
# Out:
# Department
# Finance    6
# HR         7
# IT         8
# Sales      9
# Name: Employee_ID, dtype: int64

# %%
#18.Rename Performance_Score to Performance.
df.rename(columns={"Performance_Score":"Performance"},inplace=True)
print(df.head(3))
# Out:
#    Employee_ID Employee_Name Department    City  Experience  Salary  \
# 0          101          Amit      Sales   Delhi           2   30000
# 1          102         Priya         HR  Mumbai           5   50000
# 2          103         Rahul         IT   Delhi           3   42000
#
#    Performance  Projects_Completed  Annual_Salary
# 0           75                   4         360000
# 1           88                   7         600000
# 2           82                   5         504000

# %%
#19.Find the maximum salary for each department
print(df.groupby("Department")["Salary"].max())
# Out:
# Department
# Finance    75000
# HR         78000
# IT         64000
# Sales      65000
# Name: Salary, dtype: int64

# %%
#20.Display employees with experience greater than 5 years AND performance greater than 85.
print(df[(df["Experience"]>5) |(df["Performance"]>85)])
# Out:
#     Employee_ID Employee_Name Department     City  Experience  Salary  \
# 1           102         Priya         HR   Mumbai           5   50000
# 3           104          Neha      Sales     Pune           7   65000
# 5           106         Sneha         IT    Delhi           6   60000
# 7           108         Pooja         HR  Chennai           8   70000
# 10          111         Ankit      Sales   Jaipur           4   48000
# 11          112         Meena         HR    Delhi           6   52000
# 13          114        Simran    Finance   Mumbai           9   75000
# 16          117        Manish         HR   Jaipur           7   62000
# 18          119        Suresh    Finance    Delhi           8   68000
# 20          121        Deepak      Sales  Chennai           6   56000
# 23          124         Swati         IT     Pune           7   64000
# 25          126         Komal         HR   Jaipur           8   72000
# ...

# %%
#21.Find the average experience for each department.
print(df.groupby("Department")["Experience"].mean())
# Out:
# Department
# Finance    5.166667
# HR         6.857143
# IT         3.875000
# Sales      4.444444
# Name: Experience, dtype: float64

# %%
#22.Find the total number of projects completed by each department.
print(df.groupby("Department")["Projects_Completed"].count())
# Out:
# Department
# Finance    6
# HR         7
# IT         8
# Sales      9
# Name: Projects_Completed, dtype: int64

# %%
#23.Find the total and average salary for each city.
print(df.groupby("City")["Salary"].agg(["sum","mean"]))
# Out:
#             sum          mean
# City
# Chennai  243000  60750.000000
# Delhi    501000  50100.000000
# Jaipur   182000  60666.666667
# Mumbai   407000  50875.000000
# Pune     234000  46800.000000

# %%
#24.Find the average performance score for each city.
print(df.groupby("City")["Performance"].mean())
# Out:
# City
# Chennai    87.000000
# Delhi      84.600000
# Jaipur     90.666667
# Mumbai     83.125000
# Pune       78.400000
# Name: Performance, dtype: float64

# %%
#25.Find the total salary for each Department and City.
print(df.groupby(["Department","City"])["Salary"].sum())
# Out:
# Department  City
# Finance     Delhi      123000
#             Mumbai     192000
# HR          Chennai     70000
#             Delhi      103000
#             Jaipur     134000
#             Mumbai     128000
# IT          Delhi      199000
#             Mumbai      40000
#             Pune       137000
# Sales       Chennai    173000
#             Delhi       76000
#             Jaipur      48000
#             Mumbai      47000
#             Pune        97000
# Name: Salary, dtype: int64

# %%
#26.Create a pivot table showing average Salary by Department and City.
print(pd.pivot_table(df,columns="Department",index="City",values="Salary",aggfunc="mean"))
# Out:
# Department  Finance       HR            IT         Sales
# City
# Chennai         NaN  70000.0           NaN  57666.666667
# Delhi       61500.0  51500.0  49750.000000  38000.000000
# Jaipur          NaN  67000.0           NaN  48000.000000
# Mumbai      48000.0  64000.0  40000.000000  47000.000000
# Pune            NaN      NaN  45666.666667  48500.000000

# %%
#27.Create a pivot table showing average Performance by Department and City.
print(pd.pivot_table(df,columns="Department",index="City",values="Performance",aggfunc="mean"))
# Out:
# Department  Finance    HR    IT      Sales
# City
# Chennai         NaN  89.0   NaN  86.333333
# Delhi         89.00  86.5  85.0  77.500000
# Jaipur          NaN  92.5   NaN  87.000000
# Mumbai        80.75  92.5  76.0  81.000000
# Pune            NaN   NaN  77.0  80.500000

# %%
#28.Find the employee with the highest performance score.
highest_perf = df.loc[df["Performance"].idxmax()]
print(highest_perf)
# Out:
# Employee_ID              130
# Employee_Name         Shweta
# Department                HR
# City                  Mumbai
# Experience                 9
# Salary                 78000
# Performance               97
# Projects_Completed        12
# Annual_Salary         936000
# Name: 29, dtype: object

# %%
#29.Find the department having the highest average salary.
dep_avg=df.groupby("Department")["Salary"].mean()
print(dep_avg.idxmax(), dep_avg.max())
# Out:
# HR 62142.857142857145

# %%
#30.Create a pivot table showing total Projects_Completed by Department and City.
print(pd.pivot_table(df,columns="Department",index="City",values="Projects_Completed",aggfunc="sum"))
# Out:
# Department  Finance    HR    IT  Sales
# City
# Chennai         NaN   8.0   NaN   23.0
# Delhi          17.0  15.0  27.0   10.0
# Jaipur          NaN  19.0   NaN    6.0
# Mumbai         26.0  19.0   5.0    6.0
# Pune            NaN   NaN  16.0   12.0
