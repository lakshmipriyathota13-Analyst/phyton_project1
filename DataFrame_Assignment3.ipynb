# %%
import pandas as pd

data = {
    "Order_ID": [
        1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010,
        1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020,
        1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030
    ],
    "Customer_Name": [
        "Amit", "Priya", "Rahul", "Neha", "Vikas", "Sneha", "Arjun", "Pooja",
        "Karan", "Riya", "Ankit", "Meena", "Rohit", "Simran", "Varun",
        "Kavita", "Manish", "Nisha", "Suresh", "Anjali", "Deepak", "Pallavi",
        "Raj", "Swati", "Mohit", "Komal", "Vivek", "Preeti", "Nitin", "Shweta"
    ],
    "City": [
        "Delhi", "Mumbai", "Delhi", "Pune", "Mumbai", "Delhi", "Pune", "Chennai",
        "Delhi", "Mumbai", "Jaipur", "Delhi", "Pune", "Mumbai", "Chennai",
        "Delhi", "Jaipur", "Mumbai", "Delhi", "Pune", "Chennai", "Delhi",
        "Mumbai", "Pune", "Delhi", "Jaipur", "Mumbai", "Chennai", "Delhi", "Mumbai"
    ],
    "Product": [
        "Laptop", "Mobile", "Headphones", "Laptop", "Tablet", "Mobile",
        "Laptop", "Smartwatch", "Mobile", "Headphones", "Tablet", "Laptop",
        "Mobile", "Smartwatch", "Laptop", "Headphones", "Tablet", "Mobile",
        "Laptop", "Smartwatch", "Headphones", "Mobile", "Laptop", "Tablet",
        "Mobile", "Headphones", "Laptop", "Smartwatch", "Mobile", "Tablet"
    ],
    "Category": [
        "Electronics", "Electronics", "Accessories", "Electronics", "Electronics",
        "Electronics", "Electronics", "Accessories", "Electronics", "Accessories",
        "Electronics", "Electronics", "Electronics", "Accessories", "Electronics",
        "Accessories", "Electronics", "Electronics", "Electronics", "Accessories",
        "Accessories", "Electronics", "Electronics", "Electronics", "Electronics",
        "Accessories", "Electronics", "Accessories", "Electronics", "Electronics"
    ],
    "Quantity": [
        1, 2, 3, 1, 2, 2, 1, 2, 3, 2,
        1, 1, 2, 1, 1, 3, 2, 2, 1, 1,
        2, 3, 1, 2, 2, 3, 1, 2, 3, 1
    ],
    "Unit_Price": [
        55000, 25000, 2000, 60000, 30000, 22000, 58000, 8000, 24000, 2500,
        28000, 52000, 23000, 9000, 65000, 2200, 32000, 21000, 62000, 7500,
        1800, 26000, 57000, 29000, 24000, 2500, 68000, 8500, 22000, 31000
    ],
    "Payment_Mode": [
        "UPI", "Credit Card", "Cash", "UPI", "Debit Card", "UPI",
        "Credit Card", "UPI", "Debit Card", "Cash", "UPI", "Credit Card",
        "UPI", "Debit Card", "Credit Card", "Cash", "UPI", "Debit Card",
        "Credit Card", "UPI", "Cash", "Credit Card", "UPI", "Debit Card",
        "UPI", "Cash", "Credit Card", "UPI", "Debit Card", "Credit Card"
    ],
    "Sales": [
        55000, 50000, 6000, 60000, 60000, 44000, 58000, 16000, 72000, 5000,
        28000, 52000, 46000, 9000, 65000, 6600, 64000, 42000, 62000, 7500,
        3600, 78000, 57000, 58000, 48000, 7500, 68000, 17000, 66000, 31000
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Order_ID Customer_Name     City     Product     Category  Quantity  \
# 0       1001          Amit    Delhi      Laptop  Electronics         1
# 1       1002         Priya   Mumbai      Mobile  Electronics         2
# 2       1003         Rahul    Delhi  Headphones  Accessories         3
# 3       1004          Neha     Pune      Laptop  Electronics         1
# 4       1005         Vikas   Mumbai      Tablet  Electronics         2
# 5       1006         Sneha    Delhi      Mobile  Electronics         2
# 6       1007         Arjun     Pune      Laptop  Electronics         1
# 7       1008         Pooja  Chennai  Smartwatch  Accessories         2
# 8       1009         Karan    Delhi      Mobile  Electronics         3
# 9       1010          Riya   Mumbai  Headphones  Accessories         2
# 10      1011         Ankit   Jaipur      Tablet  Electronics         1
# 11      1012         Meena    Delhi      Laptop  Electronics         1
# ...

# %%
Questions

# %%
#1.	Display the first 10 rows of the DataFrame.
print(df.head(10))
# Out:
#    Order_ID Customer_Name     City     Product     Category  Quantity  \
# 0      1001          Amit    Delhi      Laptop  Electronics         1
# 1      1002         Priya   Mumbai      Mobile  Electronics         2
# 2      1003         Rahul    Delhi  Headphones  Accessories         3
# 3      1004          Neha     Pune      Laptop  Electronics         1
# 4      1005         Vikas   Mumbai      Tablet  Electronics         2
# 5      1006         Sneha    Delhi      Mobile  Electronics         2
# 6      1007         Arjun     Pune      Laptop  Electronics         1
# 7      1008         Pooja  Chennai  Smartwatch  Accessories         2
# 8      1009         Karan    Delhi      Mobile  Electronics         3
# 9      1010          Riya   Mumbai  Headphones  Accessories         2
#
#    Unit_Price Payment_Mode  Sales
# 0       55000          UPI  55000
# 1       25000  Credit Card  50000
# 2        2000         Cash   6000
# 3       60000          UPI  60000
# ...

# %%
#2.	Display only the Customer_Name, City, Product, and Sales columns.
df[["Customer_Name","City","Product","Sales"]]
print(df.head(5))
# Out:
#    Order_ID Customer_Name    City     Product     Category  Quantity  \
# 0      1001          Amit   Delhi      Laptop  Electronics         1
# 1      1002         Priya  Mumbai      Mobile  Electronics         2
# 2      1003         Rahul   Delhi  Headphones  Accessories         3
# 3      1004          Neha    Pune      Laptop  Electronics         1
# 4      1005         Vikas  Mumbai      Tablet  Electronics         2
#
#    Unit_Price Payment_Mode  Sales
# 0       55000          UPI  55000
# 1       25000  Credit Card  50000
# 2        2000         Cash   6000
# 3       60000          UPI  60000
# 4       30000   Debit Card  60000

# %%
#3.	Find the total number of orders.
print(df["Order_ID"].count())
# Out:
# 30

# %%
#4.	Display all orders where Sales is greater than 50,000
print(df[df["Sales"]>50000])
# Out:
#     Order_ID Customer_Name     City Product     Category  Quantity  \
# 0       1001          Amit    Delhi  Laptop  Electronics         1
# 3       1004          Neha     Pune  Laptop  Electronics         1
# 4       1005         Vikas   Mumbai  Tablet  Electronics         2
# 6       1007         Arjun     Pune  Laptop  Electronics         1
# 8       1009         Karan    Delhi  Mobile  Electronics         3
# 11      1012         Meena    Delhi  Laptop  Electronics         1
# 14      1015         Varun  Chennai  Laptop  Electronics         1
# 16      1017        Manish   Jaipur  Tablet  Electronics         2
# 18      1019        Suresh    Delhi  Laptop  Electronics         1
# 21      1022       Pallavi    Delhi  Mobile  Electronics         3
# 22      1023           Raj   Mumbai  Laptop  Electronics         1
# 23      1024         Swati     Pune  Tablet  Electronics         2
# 26      1027         Vivek   Mumbai  Laptop  Electronics         1
# ...

# %%
#5.	Display customers who purchased a Laptop.
print(df[df["Product"]=="Laptop"])
# Out:
#     Order_ID Customer_Name     City Product     Category  Quantity  \
# 0       1001          Amit    Delhi  Laptop  Electronics         1
# 3       1004          Neha     Pune  Laptop  Electronics         1
# 6       1007         Arjun     Pune  Laptop  Electronics         1
# 11      1012         Meena    Delhi  Laptop  Electronics         1
# 14      1015         Varun  Chennai  Laptop  Electronics         1
# 18      1019        Suresh    Delhi  Laptop  Electronics         1
# 22      1023           Raj   Mumbai  Laptop  Electronics         1
# 26      1027         Vivek   Mumbai  Laptop  Electronics         1
#
#     Unit_Price Payment_Mode  Sales
# 0        55000          UPI  55000
# 3        60000          UPI  60000
# 6        58000  Credit Card  58000
# 11       52000  Credit Card  52000
# 14       65000  Credit Card  65000
# 18       62000  Credit Card  62000
# 22       57000          UPI  57000
# 26       68000  Credit Card  68000

# %%
#6.	Find the total sales generated from all orders.
print(df["Sales"].sum())
# Out:
# 1242200

# %%
#7.	Display orders where Quantity is greater than 2 AND Sales is greater than 20,000.
print(df[(df["Quantity"]>2 & (df["Sales"]>20000))])
# Out:
#     Order_ID Customer_Name     City     Product     Category  Quantity  \
# 0       1001          Amit    Delhi      Laptop  Electronics         1
# 1       1002         Priya   Mumbai      Mobile  Electronics         2
# 2       1003         Rahul    Delhi  Headphones  Accessories         3
# 3       1004          Neha     Pune      Laptop  Electronics         1
# 4       1005         Vikas   Mumbai      Tablet  Electronics         2
# 5       1006         Sneha    Delhi      Mobile  Electronics         2
# 6       1007         Arjun     Pune      Laptop  Electronics         1
# 7       1008         Pooja  Chennai  Smartwatch  Accessories         2
# 8       1009         Karan    Delhi      Mobile  Electronics         3
# 9       1010          Riya   Mumbai  Headphones  Accessories         2
# 10      1011         Ankit   Jaipur      Tablet  Electronics         1
# 11      1012         Meena    Delhi      Laptop  Electronics         1
# ...

# %%
#8.	Find the average sales amount.
print(df["Sales"].mean())
# Out:
# 41406.666666666664

# %%
#9.	Display customers from Delhi OR Mumbai.
print(df[(df["City"]=="Delhi")|(df["City"]=="Mumbai")])
# Out:
#     Order_ID Customer_Name    City     Product     Category  Quantity  \
# 0       1001          Amit   Delhi      Laptop  Electronics         1
# 1       1002         Priya  Mumbai      Mobile  Electronics         2
# 2       1003         Rahul   Delhi  Headphones  Accessories         3
# 4       1005         Vikas  Mumbai      Tablet  Electronics         2
# 5       1006         Sneha   Delhi      Mobile  Electronics         2
# 8       1009         Karan   Delhi      Mobile  Electronics         3
# 9       1010          Riya  Mumbai  Headphones  Accessories         2
# 11      1012         Meena   Delhi      Laptop  Electronics         1
# 13      1014        Simran  Mumbai  Smartwatch  Accessories         1
# 15      1016        Kavita   Delhi  Headphones  Accessories         3
# 17      1018         Nisha  Mumbai      Mobile  Electronics         2
# 18      1019        Suresh   Delhi      Laptop  Electronics         1
# ...

# %%
#9.	Display customers from Delhi OR Mumbai.# other method
print(df[df["City"].isin(["Delhi","Mumbai"])])
# Out:
#     Order_ID Customer_Name    City     Product     Category  Quantity  \
# 0       1001          Amit   Delhi      Laptop  Electronics         1
# 1       1002         Priya  Mumbai      Mobile  Electronics         2
# 2       1003         Rahul   Delhi  Headphones  Accessories         3
# 4       1005         Vikas  Mumbai      Tablet  Electronics         2
# 5       1006         Sneha   Delhi      Mobile  Electronics         2
# 8       1009         Karan   Delhi      Mobile  Electronics         3
# 9       1010          Riya  Mumbai  Headphones  Accessories         2
# 11      1012         Meena   Delhi      Laptop  Electronics         1
# 13      1014        Simran  Mumbai  Smartwatch  Accessories         1
# 15      1016        Kavita   Delhi  Headphones  Accessories         3
# 17      1018         Nisha  Mumbai      Mobile  Electronics         2
# 18      1019        Suresh   Delhi      Laptop  Electronics         1
# ...

# %%
#10.Add a new column called Total_Value by multiplying Quantity and Unit_Price.
df["Total_Value"]=df["Quantity"]*df["Unit_Price"]
print(df)
# Out:
#     Order_ID Customer_Name     City     Product     Category  Quantity  \
# 0       1001          Amit    Delhi      Laptop  Electronics         1
# 1       1002         Priya   Mumbai      Mobile  Electronics         2
# 2       1003         Rahul    Delhi  Headphones  Accessories         3
# 3       1004          Neha     Pune      Laptop  Electronics         1
# 4       1005         Vikas   Mumbai      Tablet  Electronics         2
# 5       1006         Sneha    Delhi      Mobile  Electronics         2
# 6       1007         Arjun     Pune      Laptop  Electronics         1
# 7       1008         Pooja  Chennai  Smartwatch  Accessories         2
# 8       1009         Karan    Delhi      Mobile  Electronics         3
# 9       1010          Riya   Mumbai  Headphones  Accessories         2
# 10      1011         Ankit   Jaipur      Tablet  Electronics         1
# 11      1012         Meena    Delhi      Laptop  Electronics         1
# ...

# %%
#11.Find the highest Sales value.
print(df["Sales"].max())
# Out:
# 78000

# %%
#12.Display all orders where the payment mode is UPI.
print(df[df["Payment_Mode"]=="UPI"])
# Out:
#     Order_ID Customer_Name     City     Product     Category  Quantity  \
# 0       1001          Amit    Delhi      Laptop  Electronics         1
# 3       1004          Neha     Pune      Laptop  Electronics         1
# 5       1006         Sneha    Delhi      Mobile  Electronics         2
# 7       1008         Pooja  Chennai  Smartwatch  Accessories         2
# 10      1011         Ankit   Jaipur      Tablet  Electronics         1
# 12      1013         Rohit     Pune      Mobile  Electronics         2
# 16      1017        Manish   Jaipur      Tablet  Electronics         2
# 19      1020        Anjali     Pune  Smartwatch  Accessories         1
# 22      1023           Raj   Mumbai      Laptop  Electronics         1
# 24      1025         Mohit    Delhi      Mobile  Electronics         2
# 27      1028        Preeti  Chennai  Smartwatch  Accessories         2
#
#     Unit_Price Payment_Mode  Sales  Total_Value
# 0        55000          UPI  55000        55000
# ...

# %%
#13.Find the total sales for each city.
print(df.groupby("City")["Sales"].sum())
# Out:
# City
# Chennai    101600
# Delhi      489600
# Jaipur      99500
# Mumbai     322000
# Pune       229500
# Name: Sales, dtype: int64

# %%
#14.Remove the Unit_Price column from the DataFrame.
df.drop("Unit_Price",axis=1,inplace=True)
print(df.head(5))
# Out:
#    Order_ID Customer_Name    City     Product     Category  Quantity  \
# 0      1001          Amit   Delhi      Laptop  Electronics         1
# 1      1002         Priya  Mumbai      Mobile  Electronics         2
# 2      1003         Rahul   Delhi  Headphones  Accessories         3
# 3      1004          Neha    Pune      Laptop  Electronics         1
# 4      1005         Vikas  Mumbai      Tablet  Electronics         2
#
#   Payment_Mode  Sales  Total_Value
# 0          UPI  55000        55000
# 1  Credit Card  50000        50000
# 2         Cash   6000         6000
# 3          UPI  60000        60000
# 4   Debit Card  60000        60000

# %%
#15.Find the average sales for each product.
print(df.groupby("Product")["Sales"].mean())
# Out:
# Product
# Headphones     5740.0
# Laptop        59625.0
# Mobile        55750.0
# Smartwatch    12375.0
# Tablet        48200.0
# Name: Sales, dtype: float64

# %%
#16.Display orders where the customer is not from Delhi.
(df[df["City"]!="Delhi"])
print(df.head(3))
# Out:
#    Order_ID Customer_Name    City     Product     Category  Quantity  \
# 0      1001          Amit   Delhi      Laptop  Electronics         1
# 1      1002         Priya  Mumbai      Mobile  Electronics         2
# 2      1003         Rahul   Delhi  Headphones  Accessories         3
#
#   Payment_Mode  Sales  Total_Value
# 0          UPI  55000        55000
# 1  Credit Card  50000        50000
# 2         Cash   6000         6000

# %%
#17.Find the number of orders for each payment mode.
print(df.groupby("Payment_Mode")["Order_ID"].count())
# Out:
# Payment_Mode
# Cash            5
# Credit Card     8
# Debit Card      6
# UPI            11
# Name: Order_ID, dtype: int64

# %%
#18.Rename the column Customer_Name to Customer.
df.rename(columns={"Customer_Name":"Customer"},inplace=True)
print(df.head(3))
# Out:
#    Order_ID Customer    City     Product     Category  Quantity Payment_Mode  \
# 0      1001     Amit   Delhi      Laptop  Electronics         1          UPI
# 1      1002    Priya  Mumbai      Mobile  Electronics         2  Credit Card
# 2      1003    Rahul   Delhi  Headphones  Accessories         3         Cash
#
#    Sales  Total_Value
# 0  55000        55000
# 1  50000        50000
# 2   6000         6000

# %%
#19.Find the maximum quantity purchased for each product.
print(df.groupby("Product")["Quantity"].max())
# Out:
# Product
# Headphones    3
# Laptop        1
# Mobile        3
# Smartwatch    2
# Tablet        2
# Name: Quantity, dtype: int64

# %%
#22.Remove the Payment_Mode column.
df.drop("Payment_Mode",axis=1,inplace=True)
print(df.head(5))

# %%
#20.Display orders where the Category is Electronics AND Sales is greater than 40,000
(df[(df["Category"]=="Electronics")&(df["Sales"]>40000)])
print(df.head(5))
# Out:
#    Order_ID Customer    City     Product     Category  Quantity  Sales  \
# 0      1001     Amit   Delhi      Laptop  Electronics         1  55000
# 1      1002    Priya  Mumbai      Mobile  Electronics         2  50000
# 2      1003    Rahul   Delhi  Headphones  Accessories         3   6000
# 3      1004     Neha    Pune      Laptop  Electronics         1  60000
# 4      1005    Vikas  Mumbai      Tablet  Electronics         2  60000
#
#    Total_Value
# 0        55000
# 1        50000
# 2         6000
# 3        60000
# 4        60000

# %%
#21.Find the total sales for each category.
print(df.groupby("Category")["Sales"].sum())
# Out:
# Category
# Accessories      78200
# Electronics    1164000
# Name: Sales, dtype: int64

# %%
#23.Find the total and average sales for each city.
print(df.groupby("City")["Sales"].mean())
# Out:
# City
# Chennai    25400.000000
# Delhi      48960.000000
# Jaipur     33166.666667
# Mumbai     40250.000000
# Pune       45900.000000
# Name: Sales, dtype: float64

# %%
#24.Find the total sales for each City and Product.
print(df.groupby(["City","Product"])["Sales"].sum())
# Out:
# City     Product
# Chennai  Headphones      3600
#          Laptop         65000
#          Smartwatch     33000
# Delhi    Headphones     12600
#          Laptop        169000
#          Mobile        308000
# Jaipur   Headphones      7500
#          Tablet         92000
# Mumbai   Headphones      5000
#          Laptop        125000
#          Mobile         92000
#          Smartwatch      9000
#          Tablet         91000
# Pune     Laptop        118000
#          Mobile         46000
#          Smartwatch      7500
#          Tablet         58000
# Name: Sales, dtype: int64

# %%
#25.Create a pivot table showing total Sales by City and Product.
print(pd.pivot_table(df,columns="City",index="Product",values="Sales",aggfunc="sum"))
# Out:
# City        Chennai     Delhi   Jaipur    Mumbai      Pune
# Product
# Headphones   3600.0   12600.0   7500.0    5000.0       NaN
# Laptop      65000.0  169000.0      NaN  125000.0  118000.0
# Mobile          NaN  308000.0      NaN   92000.0   46000.0
# Smartwatch  33000.0       NaN      NaN    9000.0    7500.0
# Tablet          NaN       NaN  92000.0   91000.0   58000.0

# %%
#26.Create a pivot table showing average Sales by Payment Mode and Category.
print(pd.pivot_table(df,columns="Category",index="City",values="Sales",aggfunc="mean"))
# Out:
# Category  Accessories   Electronics
# City
# Chennai       12200.0  65000.000000
# Delhi          6300.0  59625.000000
# Jaipur         7500.0  46000.000000
# Mumbai         7000.0  51333.333333
# Pune           7500.0  55500.000000

# %%
#27.Display the order with the highest Sales.
print(df.loc[df["Sales"].idxmax()])
# Out:
# Order_ID              1022
# Customer           Pallavi
# City                 Delhi
# Product             Mobile
# Category       Electronics
# Quantity                 3
# Sales                78000
# Total_Value          78000
# Name: 21, dtype: object

# %%
#28Find the total quantity sold for each product.
print(df.groupby("Product")["Quantity"].sum())
# Out:
# Product
# Headphones    13
# Laptop         8
# Mobile        19
# Smartwatch     6
# Tablet         8
# Name: Quantity, dtype: int64

# %%
#29.Find the average qunatity for each category.
print(df.groupby("Category")["Quantity"].mean())
# Out:
# Category
# Accessories    2.111111
# Electronics    1.666667
# Name: Quantity, dtype: float64

# %%
#30.Create a pivot table showing the total Quantity purchased by City and Category.
print(pd.pivot_table(df,columns="Category",index="City",values="Quantity",aggfunc="sum"))
# Out:
# Category  Accessories  Electronics
# City
# Chennai             6            1
# Delhi               6           16
# Jaipur              3            3
# Mumbai              3            9
# Pune                1            6
