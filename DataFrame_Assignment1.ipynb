# %%
import pandas as pd
data = {
"Employee_ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
"Name": ["Amit", "Priya", "Rahul", "Neha", "Vikas", "Sneha", "Arjun", "Pooja", "Karan", "Riya"],
"City": ["Delhi", "Mumbai", "Delhi", "Pune", "Mumbai", "Delhi", "Pune", "Chennai", "Delhi", "Mumbai"],
"Department": ["Sales", "HR", "Sales", "IT", "Sales", "HR", "Sales", "IT", "Sales", "HR"],
"Age": [25, 30, 28, 35, 24, 29, 32, 27, 26, 31],
"Salary": [30000, 45000, 38000, 55000, 28000, 42000, 50000, 40000, 35000, 47000],
"Sales": [50000, 30000, 65000, 40000, 55000, 25000, 70000, 45000, 60000, 35000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales
# 0          101   Amit    Delhi      Sales   25   30000  50000
# 1          102  Priya   Mumbai         HR   30   45000  30000
# 2          103  Rahul    Delhi      Sales   28   38000  65000
# 3          104   Neha     Pune         IT   35   55000  40000
# 4          105  Vikas   Mumbai      Sales   24   28000  55000
# 5          106  Sneha    Delhi         HR   29   42000  25000
# 6          107  Arjun     Pune      Sales   32   50000  70000
# 7          108  Pooja  Chennai         IT   27   40000  45000
# 8          109  Karan    Delhi      Sales   26   35000  60000
# 9          110   Riya   Mumbai         HR   31   47000  35000

# %% [markdown]
# # Add New Columns

# %%
# 1.Add a new column Annual_Salary by multiplying Salary by 12.

df["Annual_salary"]=df["Salary"]*12
print(df)
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales  Annual_salary
# 0          101   Amit    Delhi      Sales   25   30000  50000         360000
# 1          102  Priya   Mumbai         HR   30   45000  30000         540000
# 2          103  Rahul    Delhi      Sales   28   38000  65000         456000
# 3          104   Neha     Pune         IT   35   55000  40000         660000
# 4          105  Vikas   Mumbai      Sales   24   28000  55000         336000
# 5          106  Sneha    Delhi         HR   29   42000  25000         504000
# 6          107  Arjun     Pune      Sales   32   50000  70000         600000
# 7          108  Pooja  Chennai         IT   27   40000  45000         480000
# 8          109  Karan    Delhi      Sales   26   35000  60000         420000
# 9          110   Riya   Mumbai         HR   31   47000  35000         564000

# %%
# 2.Add a new column Bonus equal to 10% of Sales.

df["Bonus"]=df["Sales"]*10/100
print(df)
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales  Annual_salary  \
# 0          101   Amit    Delhi      Sales   25   30000  50000         360000
# 1          102  Priya   Mumbai         HR   30   45000  30000         540000
# 2          103  Rahul    Delhi      Sales   28   38000  65000         456000
# 3          104   Neha     Pune         IT   35   55000  40000         660000
# 4          105  Vikas   Mumbai      Sales   24   28000  55000         336000
# 5          106  Sneha    Delhi         HR   29   42000  25000         504000
# 6          107  Arjun     Pune      Sales   32   50000  70000         600000
# 7          108  Pooja  Chennai         IT   27   40000  45000         480000
# 8          109  Karan    Delhi      Sales   26   35000  60000         420000
# 9          110   Riya   Mumbai         HR   31   47000  35000         564000
#
#     Bonus
# 0  5000.0
# 1  3000.0
# 2  6500.0
# 3  4000.0
# 4  5500.0
# 5  2500.0
# 6  7000.0
# 7  4500.0
# 8  6000.0
# ...

# %%
# 3. Add a new column Total_Income by adding Salary and Bonus.

df["Total_income"]=df["Salary"]+df["Bonus"]
print(df)
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales  Annual_salary  \
# 0          101   Amit    Delhi      Sales   25   30000  50000         360000
# 1          102  Priya   Mumbai         HR   30   45000  30000         540000
# 2          103  Rahul    Delhi      Sales   28   38000  65000         456000
# 3          104   Neha     Pune         IT   35   55000  40000         660000
# 4          105  Vikas   Mumbai      Sales   24   28000  55000         336000
# 5          106  Sneha    Delhi         HR   29   42000  25000         504000
# 6          107  Arjun     Pune      Sales   32   50000  70000         600000
# 7          108  Pooja  Chennai         IT   27   40000  45000         480000
# 8          109  Karan    Delhi      Sales   26   35000  60000         420000
# 9          110   Riya   Mumbai         HR   31   47000  35000         564000
#
#     Bonus  Total_income
# 0  5000.0       35000.0
# 1  3000.0       48000.0
# 2  6500.0       44500.0
# ...

# %%
# 4  Add a new column Sales_Lakhs by dividing Sales by 100000.

df["Sales_lakhs"]=df["Sales"]/100000
print(df)
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales  Annual_salary  \
# 0          101   Amit    Delhi      Sales   25   30000  50000         360000
# 1          102  Priya   Mumbai         HR   30   45000  30000         540000
# 2          103  Rahul    Delhi      Sales   28   38000  65000         456000
# 3          104   Neha     Pune         IT   35   55000  40000         660000
# 4          105  Vikas   Mumbai      Sales   24   28000  55000         336000
# 5          106  Sneha    Delhi         HR   29   42000  25000         504000
# 6          107  Arjun     Pune      Sales   32   50000  70000         600000
# 7          108  Pooja  Chennai         IT   27   40000  45000         480000
# 8          109  Karan    Delhi      Sales   26   35000  60000         420000
# 9          110   Riya   Mumbai         HR   31   47000  35000         564000
#
#     Bonus  Total_income  Sales_lakhs
# 0  5000.0       35000.0         0.50
# 1  3000.0       48000.0         0.30
# ...

# %% [markdown]
# # Remove Columns

# %%
# 5. Remove the Age column from the DataFrame.
df.drop(["Age"],axis=1,inplace=True)
print(df)
# Out:
#    Employee_ID   Name     City Department  Salary  Sales  Annual_salary  \
# 0          101   Amit    Delhi      Sales   30000  50000         360000
# 1          102  Priya   Mumbai         HR   45000  30000         540000
# 2          103  Rahul    Delhi      Sales   38000  65000         456000
# 3          104   Neha     Pune         IT   55000  40000         660000
# 4          105  Vikas   Mumbai      Sales   28000  55000         336000
# 5          106  Sneha    Delhi         HR   42000  25000         504000
# 6          107  Arjun     Pune      Sales   50000  70000         600000
# 7          108  Pooja  Chennai         IT   40000  45000         480000
# 8          109  Karan    Delhi      Sales   35000  60000         420000
# 9          110   Riya   Mumbai         HR   47000  35000         564000
#
#     Bonus  Total_income  Sales_lakhs
# 0  5000.0       35000.0         0.50
# 1  3000.0       48000.0         0.30
# 2  6500.0       44500.0         0.65
# ...

# %%
#6. Remove the Department and Sales_Lakhs columns.
df.drop(["Sales_lakhs"],axis=1,inplace=True)
print(df)
# Out:
#    Employee_ID   Name     City Department  Salary  Sales  Annual_salary  \
# 0          101   Amit    Delhi      Sales   30000  50000         360000
# 1          102  Priya   Mumbai         HR   45000  30000         540000
# 2          103  Rahul    Delhi      Sales   38000  65000         456000
# 3          104   Neha     Pune         IT   55000  40000         660000
# 4          105  Vikas   Mumbai      Sales   28000  55000         336000
# 5          106  Sneha    Delhi         HR   42000  25000         504000
# 6          107  Arjun     Pune      Sales   50000  70000         600000
# 7          108  Pooja  Chennai         IT   40000  45000         480000
# 8          109  Karan    Delhi      Sales   35000  60000         420000
# 9          110   Riya   Mumbai         HR   47000  35000         564000
#
#     Bonus  Total_income
# 0  5000.0       35000.0
# 1  3000.0       48000.0
# 2  6500.0       44500.0
# 3  4000.0       59000.0
# 4  5500.0       33500.0
# ...

# %%
# 7. Remove the Employee_ID column permanently using inplace=True

df.drop(["Employee_ID"],axis=1,inplace=True)
print(df)
# Out:
#     Name     City Department  Salary  Sales  Annual_salary   Bonus  \
# 0   Amit    Delhi      Sales   30000  50000         360000  5000.0
# 1  Priya   Mumbai         HR   45000  30000         540000  3000.0
# 2  Rahul    Delhi      Sales   38000  65000         456000  6500.0
# 3   Neha     Pune         IT   55000  40000         660000  4000.0
# 4  Vikas   Mumbai      Sales   28000  55000         336000  5500.0
# 5  Sneha    Delhi         HR   42000  25000         504000  2500.0
# 6  Arjun     Pune      Sales   50000  70000         600000  7000.0
# 7  Pooja  Chennai         IT   40000  45000         480000  4500.0
# 8  Karan    Delhi      Sales   35000  60000         420000  6000.0
# 9   Riya   Mumbai         HR   47000  35000         564000  3500.0
#
#    Total_income
# 0       35000.0
# 1       48000.0
# 2       44500.0
# 3       59000.0
# 4       33500.0
# 5       44500.0
# 6       57000.0
# 7       44500.0
# 8       41000.0
# 9       50500.0

# %% [markdown]
# # Remove Rows

# %%
# 8. Remove the first row from the DataFrame.
df.drop([0],axis=0,inplace=True)
print(df)
# Out:
#     Name     City Department  Salary  Sales  Annual_salary   Bonus  \
# 2  Rahul    Delhi      Sales   38000  65000         456000  6500.0
# 3   Neha     Pune         IT   55000  40000         660000  4000.0
# 4  Vikas   Mumbai      Sales   28000  55000         336000  5500.0
# 5  Sneha    Delhi         HR   42000  25000         504000  2500.0
# 6  Arjun     Pune      Sales   50000  70000         600000  7000.0
# 7  Pooja  Chennai         IT   40000  45000         480000  4500.0
# 8  Karan    Delhi      Sales   35000  60000         420000  6000.0
# 9   Riya   Mumbai         HR   47000  35000         564000  3500.0
#
#    Total_income
# 2       44500.0
# 3       59000.0
# 4       33500.0
# 5       44500.0
# 6       57000.0
# 7       44500.0
# 8       41000.0
# 9       50500.0

# %%
import pandas as pd
data = {
"Employee_ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
"Name": ["Amit", "Priya", "Rahul", "Neha", "Vikas", "Sneha", "Arjun", "Pooja", "Karan", "Riya"],
"City": ["Delhi", "Mumbai", "Delhi", "Pune", "Mumbai", "Delhi", "Pune", "Chennai", "Delhi", "Mumbai"],
"Department": ["Sales", "HR", "Sales", "IT", "Sales", "HR", "Sales", "IT", "Sales", "HR"],
"Age": [25, 30, 28, 35, 24, 29, 32, 27, 26, 31],
"Salary": [30000, 45000, 38000, 55000, 28000, 42000, 50000, 40000, 35000, 47000],
"Sales": [50000, 30000, 65000, 40000, 55000, 25000, 70000, 45000, 60000, 35000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales
# 0          101   Amit    Delhi      Sales   25   30000  50000
# 1          102  Priya   Mumbai         HR   30   45000  30000
# 2          103  Rahul    Delhi      Sales   28   38000  65000
# 3          104   Neha     Pune         IT   35   55000  40000
# 4          105  Vikas   Mumbai      Sales   24   28000  55000
# 5          106  Sneha    Delhi         HR   29   42000  25000
# 6          107  Arjun     Pune      Sales   32   50000  70000
# 7          108  Pooja  Chennai         IT   27   40000  45000
# 8          109  Karan    Delhi      Sales   26   35000  60000
# 9          110   Riya   Mumbai         HR   31   47000  35000

# %%
#9. Remove the row having Employee_ID = 105.    
df=df.drop(df[df["Employee_ID"]==105].index)
print(df.head)
# Out:
# <bound method NDFrame.head of    Employee_ID   Name     City Department  Age  Salary  Sales
# 0          101   Amit    Delhi      Sales   25   30000  50000
# 1          102  Priya   Mumbai         HR   30   45000  30000
# 2          103  Rahul    Delhi      Sales   28   38000  65000
# 3          104   Neha     Pune         IT   35   55000  40000
# 5          106  Sneha    Delhi         HR   29   42000  25000
# 6          107  Arjun     Pune      Sales   32   50000  70000
# 7          108  Pooja  Chennai         IT   27   40000  45000
# 8          109  Karan    Delhi      Sales   26   35000  60000
# 9          110   Riya   Mumbai         HR   31   47000  35000>

# %%
#10. Remove the last two rows from the DataFrame.
df=df.drop(df.tail(2).index)
print(df)
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales
# 0          101   Amit    Delhi      Sales   25   30000  50000
# 1          102  Priya   Mumbai         HR   30   45000  30000
# 2          103  Rahul    Delhi      Sales   28   38000  65000
# 3          104   Neha     Pune         IT   35   55000  40000
# 5          106  Sneha    Delhi         HR   29   42000  25000
# 6          107  Arjun     Pune      Sales   32   50000  70000
# 7          108  Pooja  Chennai         IT   27   40000  45000

# %%
import pandas as pd
data = {
"Employee_ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
"Name": ["Amit", "Priya", "Rahul", "Neha", "Vikas", "Sneha", "Arjun", "Pooja", "Karan", "Riya"],
"City": ["Delhi", "Mumbai", "Delhi", "Pune", "Mumbai", "Delhi", "Pune", "Chennai", "Delhi", "Mumbai"],
"Department": ["Sales", "HR", "Sales", "IT", "Sales", "HR", "Sales", "IT", "Sales", "HR"],
"Age": [25, 30, 28, 35, 24, 29, 32, 27, 26, 31],
"Salary": [30000, 45000, 38000, 55000, 28000, 42000, 50000, 40000, 35000, 47000],
"Sales": [50000, 30000, 65000, 40000, 55000, 25000, 70000, 45000, 60000, 35000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales
# 0          101   Amit    Delhi      Sales   25   30000  50000
# 1          102  Priya   Mumbai         HR   30   45000  30000
# 2          103  Rahul    Delhi      Sales   28   38000  65000
# 3          104   Neha     Pune         IT   35   55000  40000
# 4          105  Vikas   Mumbai      Sales   24   28000  55000
# 5          106  Sneha    Delhi         HR   29   42000  25000
# 6          107  Arjun     Pune      Sales   32   50000  70000
# 7          108  Pooja  Chennai         IT   27   40000  45000
# 8          109  Karan    Delhi      Sales   26   35000  60000
# 9          110   Riya   Mumbai         HR   31   47000  35000

# %% [markdown]
# # Filter Rows

# %%
#11. Display employees whose Salary is greater than 40,000.
print(df[df["Salary"]>40000])
# Out:
#    Employee_ID   Name    City Department  Age  Salary  Sales
# 1          102  Priya  Mumbai         HR   30   45000  30000
# 3          104   Neha    Pune         IT   35   55000  40000
# 5          106  Sneha   Delhi         HR   29   42000  25000
# 6          107  Arjun    Pune      Sales   32   50000  70000
# 9          110   Riya  Mumbai         HR   31   47000  35000

# %%
#12. Display employees whose Sales are less than 50,000.
print(df[df["Sales"]<50000])
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales
# 1          102  Priya   Mumbai         HR   30   45000  30000
# 3          104   Neha     Pune         IT   35   55000  40000
# 5          106  Sneha    Delhi         HR   29   42000  25000
# 7          108  Pooja  Chennai         IT   27   40000  45000
# 9          110   Riya   Mumbai         HR   31   47000  35000

# %%
#13. Display employees who belong to the Sales department.
print(df[df["Department"]=="Sales"])
# Out:
#    Employee_ID   Name    City Department  Age  Salary  Sales
# 0          101   Amit   Delhi      Sales   25   30000  50000
# 2          103  Rahul   Delhi      Sales   28   38000  65000
# 4          105  Vikas  Mumbai      Sales   24   28000  55000
# 6          107  Arjun    Pune      Sales   32   50000  70000
# 8          109  Karan   Delhi      Sales   26   35000  60000

# %%
#14. Display employees who are from Delhi.
print(df[df["City"]=="Delhi"])
# Out:
#    Employee_ID   Name   City Department  Age  Salary  Sales
# 0          101   Amit  Delhi      Sales   25   30000  50000
# 2          103  Rahul  Delhi      Sales   28   38000  65000
# 5          106  Sneha  Delhi         HR   29   42000  25000
# 8          109  Karan  Delhi      Sales   26   35000  60000

# %% [markdown]
# # AND Condition

# %%
#15. Display employees whose Salary is greater than 40,000 AND Sales are greater than 50,000.

print(df [(df ["Salary"]>40000) & (df["Sales"]>50000 ) ]  )
# Out:
#    Employee_ID   Name  City Department  Age  Salary  Sales
# 6          107  Arjun  Pune      Sales   32   50000  70000

# %%
#16. Display employees who are from Delhi AND belong to the Sales department.
print (df[(df["City"]=="Delhi")& (df["Department"]=="Sales")  ])
# Out:
#    Employee_ID   Name   City Department  Age  Salary  Sales
# 0          101   Amit  Delhi      Sales   25   30000  50000
# 2          103  Rahul  Delhi      Sales   28   38000  65000
# 8          109  Karan  Delhi      Sales   26   35000  60000

# %% [markdown]
# # OR Condition

# %%
#17. Display employees who are from Delhi OR Mumbai.

print(df[(df["City"]=="Delhi")|(df["City"]=="Mumbai") ])
# Out:
#    Employee_ID   Name    City Department  Age  Salary  Sales
# 0          101   Amit   Delhi      Sales   25   30000  50000
# 1          102  Priya  Mumbai         HR   30   45000  30000
# 2          103  Rahul   Delhi      Sales   28   38000  65000
# 4          105  Vikas  Mumbai      Sales   24   28000  55000
# 5          106  Sneha   Delhi         HR   29   42000  25000
# 8          109  Karan   Delhi      Sales   26   35000  60000
# 9          110   Riya  Mumbai         HR   31   47000  35000

# %%
#18. Display employees whose Salary is less than 30,000 OR Sales are greater than 60,000.

print(df[(df["Salary"]<30000)|(df["Sales"]>60000)])
# Out:
#    Employee_ID   Name    City Department  Age  Salary  Sales
# 2          103  Rahul   Delhi      Sales   28   38000  65000
# 4          105  Vikas  Mumbai      Sales   24   28000  55000
# 6          107  Arjun    Pune      Sales   32   50000  70000

# %% [markdown]
# # NOT Condition

# %%
#19. Display employees who are NOT from Delhi.

print(df[ df["City"]!="Delhi"  ])
# Out:
#    Employee_ID   Name     City Department  Age  Salary  Sales
# 1          102  Priya   Mumbai         HR   30   45000  30000
# 3          104   Neha     Pune         IT   35   55000  40000
# 4          105  Vikas   Mumbai      Sales   24   28000  55000
# 6          107  Arjun     Pune      Sales   32   50000  70000
# 7          108  Pooja  Chennai         IT   27   40000  45000
# 9          110   Riya   Mumbai         HR   31   47000  35000

# %% [markdown]
# # Rename Columns

# %%
# 20. Rename the following columns:
● Name → Employee_Name
● City → Location
● Salary → Monthly_Salary

# %%
df.rename(columns={"Name":"Employee_Name"},inplace=True)
print(df)
# Out:
#    Employee_ID Employee_Name     City Department  Age  Salary  Sales
# 0          101          Amit    Delhi      Sales   25   30000  50000
# 1          102         Priya   Mumbai         HR   30   45000  30000
# 2          103         Rahul    Delhi      Sales   28   38000  65000
# 3          104          Neha     Pune         IT   35   55000  40000
# 4          105         Vikas   Mumbai      Sales   24   28000  55000
# 5          106         Sneha    Delhi         HR   29   42000  25000
# 6          107         Arjun     Pune      Sales   32   50000  70000
# 7          108         Pooja  Chennai         IT   27   40000  45000
# 8          109         Karan    Delhi      Sales   26   35000  60000
# 9          110          Riya   Mumbai         HR   31   47000  35000

# %%
df.rename(columns={"city":"Location","Salary":"Monthly_Salary"})
print(df)
# Out:
#    Employee_ID Employee_Name     City Department  Age  Salary  Sales
# 0          101          Amit    Delhi      Sales   25   30000  50000
# 1          102         Priya   Mumbai         HR   30   45000  30000
# 2          103         Rahul    Delhi      Sales   28   38000  65000
# 3          104          Neha     Pune         IT   35   55000  40000
# 4          105         Vikas   Mumbai      Sales   24   28000  55000
# 5          106         Sneha    Delhi         HR   29   42000  25000
# 6          107         Arjun     Pune      Sales   32   50000  70000
# 7          108         Pooja  Chennai         IT   27   40000  45000
# 8          109         Karan    Delhi      Sales   26   35000  60000
# 9          110          Riya   Mumbai         HR   31   47000  35000
