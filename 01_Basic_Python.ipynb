# %% [raw]
# 1. Write a Python program to print "Hello, Python!".
# 2. Store your name, age, and city in variables and display them.
# 3. Take two numbers from the user and display their sum.
# 4. Take two numbers and display their addition, subtraction, multiplication, and division.
# 5. Write a program to calculate the area of a rectangle.
# 6. Write a program to calculate the area of a circle.
# 7. Write a program to convert Celsius into Fahrenheit.
# 8. Take a student's name and marks and display the details.
# 9. Write a program to calculate Simple Interest using Principal, Rate, and Time.
# 10. Write a program to swap the values of two variables.

# %%
print("Hello Python")
# Out:
# Hello Phython

# %%
name=input("enter your Name")
age=int(input("enter your age"))
city=input("enter your city")
print("\n---Your Details---")
print(f"Name:{name.title()}")
print(f"Age:{age}")
print(f"City:{city.capitalize()}")
# Out:
# enter your Name lakshmi priya thota
# enter your age 27
# enter your city guntur
# ---Your Details---
# Name:Lakshmi Priya Thota
# Age:27
# City:Guntur

# %%
Num1=int(input("enter your first no"))
Num2=int(input("enter your second no"))
Num3=Num1+Num2

print(Num3,"is the result")
# Out:
# enter your first no 20
# enter your second no 25
# 45 is the result

# %%
Num1=int(input("enter your first no"))
Num2=int(input("enter your second no"))
Num3=Num1+Num2
print("The Sum is",Num3)
Num3=Num1-Num2
print("The Subtraction is",Num3)
Num3=Num1*Num2
print("The Multiplication is",Num3)
Num3=Num1/Num2
print("The division is",Num3)
# Out:
# enter your first no 50
# enter your second no 25
# The Sum is 75
# The Subtraction is 25
# The Multiplication is 1250
# The division is 2.0

# %%
length=int(input("enter no"))
width=int(input("enter  no"))
Area=length*width
print(f"The area of Rectangle:{Area}")
# Out:
# enter no 5
# enter  no 6
# The area of Rectangle:30

# %%
radius=float(input("enter radius"))
area=3.14*radius*radius
print(f"Area of Circle is:{area}")
# Out:
# enter radius 5
# Area of Circle is:78.5

# %%
celsius=float(input("enter celsius"))
fahrenheit=celsius*(9/5)+32
print(f"The temperature in fahrenheit is:{fahrenheit}")
# Out:
# enter celsius 100
# The temperature in fahrenheit is:212.0

# %%
Name=input("enter student name")
Marks=int(input("enter marks"))
print("\n---Student Details---")
print(f"Student Name is:{Name.title()}")
print(f"Marks Obtained:{Marks}")
# Out:
# enter student name pradeep kumar mathangi
# enter marks 95
# ---Student Details---
# Student Name is:Pradeep Kumar Mathangi
# Marks Obtained:95

# %%
principle=float(input("enter amount"))
rate=float(input("enter rate"))
time=float(input("enter time")) 
SI=principle*rate*time
print(f"Simple Intrest is:{SI}")
# Out:
# enter amount 2000
# enter rate 1.2
# enter time 1
# Simple Intrest is:2400.0

# %%
a=10
b=15
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# a= 15
# b= 10
